# %% [markdown]
# # Tutorials
#
# ----
#
# ###### Links on what to Study Next
#
#
# - [Study-Material](/tree/Cookbook/Tutorials/Study-Material.ipynb)
#
#
#
# ###### Notebook
#
#
# - [Jupyter Tips on Markdown](/tree/Cookbook/Tutorials/Jupyter_Tips.ipynb)
#
#
# - [Jupyter Cell Magics](/tree/Cookbook/Tutorials/Jupyter_Cell_Magics.ipynb)
#
#
# ----
#
# ###### Source code Version control
#
#
# - [GitHub setup](/tree/Cookbook/Tutorials/GitHub.ipynb)
#
#
# ----
#
# ###### Automation
#
# - [Conda tips](/tree/Cookbook/Tutorials/Conda_Tips.ipynb)
#
#
# - [Python tips](/tree/Cookbook/Tutorials/Python_Tips.ipynb)
#
#
# - [UnitTest](/tree/Cookbook/Tutorials/UnitTest.ipynb)
#
#
# - [Django tips](/tree/Cookbook/Tutorials/Django_Tips.ipynb)
#
#
# - [Selenium](/tree/Cookbook/Tutorials/Selenium.ipynb)
#
#
# ----
#
#
# ###### Node
#
#
# - [Node Angular2 Protractor Jasmine JavaScript](/tree/Cookbook/Tutorials/Node.ipynb)
#
#
# - [HTML5 CSS3 JavaScript](/tree/Cookbook/Tutorials/HTML5-CSS3-JavaScript.ipynb)
#
#
# ----
#
# ###### Mobile
#
#
# - [Android setup](/tree/Cookbook/Tutorials/Android_Setup.ipynb)
#
#
# - [Appium tips](/tree/Cookbook/Tutorials/Appium_Tips.ipynb)
#
#
# ----
#
# ###### Roadmap
#
#
# - [Java](/tree/Cookbook/Tutorials/Java.ipynb)
#
# ------

# %% [markdown]
# # Practice Applications
#
# ### Mobile
#
# - [Appium Chess program](/tree/python/Appium/Appium-Chess-Exploratory-Nexus6P-api16.ipynb)  -  [full link](http://localhost:8888/notebooks/python/Appium/Appium-Chess-Exploratory-Nexus6P-api16.ipynb)
#
#
# ### Selenium
#
# - [DJango & Selenium](/tree/python/Django/DJango-Selenium.ipynb)
#
#
# - [Selenium-Beginners-Master](/tree/python/Selenium/selenium-beginners-master/Selenium-Beginners-Master-afterloading.ipynb)
#
#
#
# ### Pandas
#
# - [Pandas-Intro Practice](/tree/python/pandas/Pandas-Intro.ipynb)
#
#
# - [Pandas from July12 MeetUp](/tree/python/pandas/pyDataTO/July12Meetup.ipynb)
#
#
# ### JIRA Report project
#
#
# - [Practice](/tree/python/JIRA-Report/Read-Table.ipynb)
#
#
#
# ### Training - Cheat Sheets
#
# - [Collection-1 Practice](/tree/python/Training/PracticeReference/Collection_1.ipynb)
#
#
# - [Quizes](/tree/python/Training/Quizes/Quizes.ipynb)
#
#
# ### Test Methodology
#
#
# - [UnitTest](/tree/python/TestMethodology/UnitTest_1.ipynb)
#
#
# - [PyTest](/tree/python/TestMethodology/pytest/RunPytest.ipynb)
#
#
#
#
# ### Utilities - small helpful python bits /programs
#
# - [organize EXPs](/tree/python/Utilities/organizeEXPs/ListSubdirectories.ipynb)
