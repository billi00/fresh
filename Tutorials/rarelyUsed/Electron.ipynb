# %% [markdown]
# # Electron Official
#
#
# - https://github.com/electron/electron
#
#
#
# - https://electron.atom.io/blog/2016/08/16/npm-install-electron
#
#
#
# - https://electron.atom.io/blog/2016/08/16/npm-install-electron
#
#
#
#
#
#
# # Electron Tutorials
#
#
#
# - Red Stapler: https://redstapler.co/tutorials/electron-tutorial/
#
#
#
# - Creating Desktop App with Electron: https://www.youtube.com/watch?v=ojX5yz35v4M
#
#
#
#
# - Angular2 & Electron: https://auth0.com/blog/create-a-desktop-app-with-angular-2-and-electron/
#
#
#
#
# - Building Package: http://blog.soulserv.net/building-a-package-featuring-electron-as-a-stand-alone-application/
#
#
#
#
#
# -
#
#
#
# -
#
#
#
# -
#
#
#
# -
#
#
#
# -
#
#
# ### Spectron
#
# - https://www.wintellect.com/end-end-testing-electron-apps-spectron/
#
#
#
# -

# %% [markdown]
# # electron app
#
#
# ###### npm init
#
#     > npm init
#
#
# - set package.json parameters
#
#     {
#       "name": "electron.app",
#       "version": "1.0.0",
#       "description": "https://www.youtube.com/watch?v=sJFuMKPfpfs&t=237s",
#       "main": "main.js",
#       "scripts": {
#         "start": "electron .",
#         "test": "echo \"Error: no test specified\" && exit 1"
#       },
#       "author": "bbb",
#       "license": "ISC",
#       "devDependencies": {
#         "electron": "^1.7.5",
#         "electron-packager": "^9.0.0"
#       }
#     }
#
# - alternative: "electron ./app" if application located in subfolder
#
# ###### install electron package
#
#     > npm install electron --save-dev
#
#
# ###### create main.js
#
#     const electron = require('electron');
#     const app = electron.app;
#     const BrowserWindow = electron.BrowserWindow;
#
#     // bind app with event "ready" when app is loaded completely
#     app.on('ready', function() {
#       var mainWindow  = new BrowserWindow({width: 800, height: 600,backgroundColor: '#2e2c29'});
#       mainWindow.loadURL('https://github.com');
#     });
#
#
# ###### alternative main.js
#
#     const electron = require('electron');
#     const app = electron.app;
#     const path = require('path');
#     const url = require('url');
#     const BrowserWindow = electron.BrowserWindow;
#
#     app.on('ready',function(){
#       var mainWindow = new BrowserWindow({width: 800, height: 600, backgroundColor: '#2e2c29'});
#       mainWindow.loadURL(url.format({
#         pathname: path.join(__dirname, 'index.html'),
#         protocol: 'file:',
#         slashes: true
#       }));
#     });
#
#
# ###### create index.html
#
#     <html>
#     <head>
#       <link rel="stylesheet" type="text/css" href="style.css">
#     </head>
#     <body>
#       <h1>Hello World</h1>
#     </body>
#     </html>
#
#
# ###### create style.css
#
#     body {color: red;}
#
#
# ######  install electron-packager
#
#     > npm install -g electron-packager
#
#
# ###### create electron.app installation
#
#
#     > electron-packager .
